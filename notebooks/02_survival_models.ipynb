# %%
import numpy as np
import pandas as pd
from pathlib import Path

from sklearn.model_selection import train_test_split, RandomizedSearchCV

from sksurv.util import Surv
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.ensemble import RandomSurvivalForest, GradientBoostingSurvivalAnalysis
from sksurv.metrics import concordance_index_censored

from joblib import dump
BASE_DIR = Path("..").resolve()
DATA_DIR = BASE_DIR / "data"
MODELS_DIR = BASE_DIR / "models"
MODELS_DIR.mkdir(exist_ok=True, parents=True)

df = pd.read_parquet(DATA_DIR / "scania_processed.parquet")
df.head(), df.shape
# Out:
# (        171_0     666_0     837_0    167_0      167_1       167_2       167_3  \
#  0  10189950.0  372685.0   41670.0      0.0   811605.0   1644061.0    560460.0
#  1   5648790.0  289371.0   68717.0  10415.0  9137870.0  74655621.0  45991626.0
#  2   7603590.0  230831.0  100121.0   5918.0  8225139.0  17004223.0  10504195.0
#  3   4842780.0  210381.0  152385.0   7128.0  4342398.0  13348382.0  11538870.0
#  4   6623040.0  280531.0  164673.0      0.0   513466.0    693990.0    350295.0
#
#          167_4       167_6      167_7  ...  Spec_7_Cat0  Spec_7_Cat1  \
#  0    873435.0         0.0        0.0  ...         True        False
#  1  65888583.0   5813857.0     3351.0  ...        False         True
#  2  30792854.0  27370868.0  3819383.0  ...        False         True
#  3  30085352.0  53625651.0  1225967.0  ...        False         True
#  4    735390.0       570.0        0.0  ...        False         True
#
#     Spec_7_Cat2  Spec_7_Cat4  Spec_7_Cat5  Spec_7_Cat6  Spec_7_Cat7  RUL  \
#  0        False        False        False        False        False  2.6
#  1        False        False        False        False        False  0.8
#  2        False        False        False        False        False  2.2
#  3        False        False        False        False        False  7.0
#  4        False        False        False        False        False  2.8
#
#     in_study_repair  vehicle_id
#  0                0           0
#  1                0           2
#  2                0           3
#  3                0           4
#  4                0           5
#
#  [5 rows x 79 columns],
#  (23550, 79))

# %%
feature_cols = [c for c in df.columns if c not in ["RUL", "in_study_repair", "vehicle_id"]]

X = df[feature_cols]
y_time  = df["RUL"].astype(float)
y_event = df["in_study_repair"].astype(bool)

X_train, X_test, y_time_train, y_time_test, y_event_train, y_event_test = \
    train_test_split(
        X, y_time, y_event,
        test_size=0.2,
        random_state=12345,
        stratify=y_event
    )

y_train = Surv.from_arrays(event=y_event_train.to_numpy(),
                           time=y_time_train.to_numpy())
y_test = Surv.from_arrays(event=y_event_test.to_numpy(),
                          time=y_time_test.to_numpy())

X_train.shape, X_test.shape
# Out:
# ((18840, 76), (4710, 76))

# %%
cph = CoxPHSurvivalAnalysis()
cph.fit(X_train, y_train)

pred_train_cph = cph.predict(X_train)
pred_test_cph  = cph.predict(X_test)

cph_c_train = concordance_index_censored(y_event_train, y_time_train, pred_train_cph)[0]
cph_c_test  = concordance_index_censored(y_event_test, y_time_test, pred_test_cph)[0]

print("CPH C-index train:", cph_c_train)
print("CPH C-index test :", cph_c_test)
# Out:
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=3.63911e-21): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=9.16553e-22): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=3.20093e-22): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=5.49076e-22): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=2.04779e-22): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=7.55883e-23): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=2.77963e-23): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=1.02307e-23): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=3.76571e-24): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=1.38561e-24): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=5.09756e-25): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=1.87531e-25): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=6.89891e-26): result may not be accurate.
#   delta = solve(
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=2.53797e-26): result may not be accurate.
#   delta = solve(
# CPH C-index train: 0.6855111429596336
# CPH C-index test : 0.6475524641836975
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\linear_model\coxph.py:492: LinAlgWarning: Ill-conditioned matrix (rcond=9.33668e-27): result may not be accurate.
#   delta = solve(

# %%
rsf = RandomSurvivalForest(
    n_estimators=200,
    random_state=12345,
    n_jobs=-1,
    oob_score=True
)

param_dist_rsf = {
    "n_estimators": [100, 200, 300, 400],
    "max_depth": [5, 15, 30, 100, 250],
    "min_samples_split": [10, 15, 20, 30, 50],
    "min_samples_leaf": [5, 10, 20],
}

rsf_cv = RandomizedSearchCV(
    rsf,
    param_distributions=param_dist_rsf,
    n_iter=15,
    cv=5,
    n_jobs=-1,
    random_state=12345
)

rsf_cv.fit(X_train, y_train)
print("Best RSF params:", rsf_cv.best_params_)
rsf_best = rsf_cv.best_estimator_

pred_train_rsf = rsf_best.predict(X_train)
pred_test_rsf  = rsf_best.predict(X_test)

rsf_c_train = concordance_index_censored(y_event_train, y_time_train, pred_train_rsf)[0]
rsf_c_test  = concordance_index_censored(y_event_test, y_time_test, pred_test_rsf)[0]

print("RSF C-index train:", rsf_c_train)
print("RSF C-index test :", rsf_c_test)
# Out:
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 5 fits failed out of a total of 75.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\_utils.py", line 72, in __call__
#     return self.func(**kwargs)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\ensemble\_forest.py", line 188, in _parallel_build_trees
#     tree._fit(
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\tree\tree.py", line 353, in _fit
#     builder.build(self.tree_, X, y_numeric, sample_weight, missing_values_in_feature_mask)
#   File "sklearn/tree/_tree.pyx", line 141, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 256, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 911, in sklearn.tree._tree.Tree._add_node
#   File "sklearn/tree/_tree.pyx", line 880, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn/tree/_utils.pyx", line 29, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 26378240 bytes
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 184, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer="threads")(
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# MemoryError: could not allocate 26378240 bytes
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 204, in fit
#     self._set_oob_score_and_attributes(X, (event, time))
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 220, in _set_oob_score_and_attributes
#     p_estimator = estimator.predict(X[unsampled_indices, :], check_input=False)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\tree\tree.py", line 480, in predict
#     return chf[:, self.is_event_time_].sum(1)
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 9.11 MiB for an array with shape (213, 5603) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 204, in fit
#     self._set_oob_score_and_attributes(X, (event, time))
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 220, in _set_oob_score_and_attributes
#     p_estimator = estimator.predict(X[unsampled_indices, :], check_input=False)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\tree\tree.py", line 480, in predict
#     return chf[:, self.is_event_time_].sum(1)
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 8.84 MiB for an array with shape (212, 5466) and data type float64
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\_utils.py", line 72, in __call__
#     return self.func(**kwargs)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 607, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\ensemble\_forest.py", line 188, in _parallel_build_trees
#     tree._fit(
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\tree\tree.py", line 353, in _fit
#     builder.build(self.tree_, X, y_numeric, sample_weight, missing_values_in_feature_mask)
#   File "sklearn/tree/_tree.pyx", line 141, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 256, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn/tree/_tree.pyx", line 911, in sklearn.tree._tree.Tree._add_node
#   File "sklearn/tree/_tree.pyx", line 880, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn/tree/_utils.pyx", line 29, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 6578176 bytes
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 184, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer="threads")(
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 2072, in __call__
#     return output if self.return_generator else list(output)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 1682, in _get_outputs
#     yield from self._retrieve()
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 1784, in _retrieve
#     self._raise_error_fast()
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 1859, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 758, in get_result
#     return self._return_or_raise()
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\joblib\parallel.py", line 773, in _return_or_raise
#     raise self._result
# MemoryError: could not allocate 6578176 bytes
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 204, in fit
#     self._set_oob_score_and_attributes(X, (event, time))
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\ensemble\forest.py", line 220, in _set_oob_score_and_attributes
#     p_estimator = estimator.predict(X[unsampled_indices, :], check_input=False)
#   File "e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sksurv\tree\tree.py", line 480, in predict
#     return chf[:, self.is_event_time_].sum(1)
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 9.11 MiB for an array with shape (213, 5607) and data type float64
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# e:\work\project\scania_rul_survival\scania_rul_env\lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [       nan 0.67927429 0.70180718        nan        nan 0.70341711
#  0.70188043 0.70341711 0.7020888  0.70259477 0.70050989 0.70073285
#  0.67773398 0.70356424 0.70073405]
#   warnings.warn(
# Best RSF params: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_depth': 30}
# RSF C-index train: 0.950728202903198
# RSF C-index test : 0.7167915116191169

# %%
gbsa = GradientBoostingSurvivalAnalysis(random_state=12345)

param_dist_gb = {
    "n_estimators": [50, 100, 200],
    "min_samples_split": [30, 50],
    "min_samples_leaf": [5, 10, 20],
    "learning_rate": [0.5, 1.0],
    "max_depth": [1, 5, 6],
}

gbsa_cv = RandomizedSearchCV(
    gbsa,
    param_distributions=param_dist_gb,
    n_iter=15,
    cv=5,
    n_jobs=-1,
    random_state=12345
)

gbsa_cv.fit(X_train, y_train)
print("Best GBSA params:", gbsa_cv.best_params_)
gbsa_best = gbsa_cv.best_estimator_

pred_train_gb = gbsa_best.predict(X_train)
pred_test_gb  = gbsa_best.predict(X_test)

gbsa_c_train = concordance_index_censored(y_event_train, y_time_train, pred_train_gb)[0]
gbsa_c_test  = concordance_index_censored(y_event_test, y_time_test, pred_test_gb)[0]

print("GBSA C-index train:", gbsa_c_train)
print("GBSA C-index test :", gbsa_c_test)
# Out:
# Best GBSA params: {'n_estimators': 100, 'min_samples_split': 30, 'min_samples_leaf': 20, 'max_depth': 6, 'learning_rate': 0.5}
# GBSA C-index train: 0.8862393195097956
# GBSA C-index test : 0.706968412344234

# %%
dump(rsf_best, MODELS_DIR / "rsf_best.joblib")
# Out:
# ['E:\\work\\project\\scania_rul_survival\\models\\rsf_best.joblib']
